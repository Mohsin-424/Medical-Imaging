# %% [markdown]
# ### Training model

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp -r drive/MyDrive/IFT780/TP3/prog/* .

#!pip install -r requirements.txt
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# La commande pour faire une prédiction sur notre meilleur modèle est la suivante

# %%
# !python train.py best_model --model=UNet --dataset='./02Heart.hdf5' --model_depth=5 --num-epochs=30 --batch_size=10 --predict
# Out:
# train.py:99: UserWarning: The directory best_model already exists, some files may be overwritten
#   warnings.warn(f"The directory {args.exp_name} already exists, some files may be overwritten")
# Not using data augmentation
# predicting the mask of a randomly selected image from test set
# <Figure size 1000x1000 with 4 Axes>

# %% [markdown]
# Affichage de l'image de l'image (utile sur google colab)

# %%
from IPython.display import Image
Image('best_model/prediction.png')

# %% [markdown]
# Exemple de recherche d'hyperparamètres sur le learning rate :

# %%
# !python3 train.py learning_search --model=UNet --dataset='./02Heart.hdf5' --tune --lr 0.01 0.001 0.0001 --num-epochs=10
# Out:
# train.py:99: UserWarning: The directory learning_search already exists, some files may be overwritten
#   warnings.warn(f"The directory {args.exp_name} already exists, some files may be overwritten")
# Not using data augmentation
# Training UNet for 10 epochs
# Epoch: 1 of 10
# 100% 64/64 [01:02<00:00,  1.03it/s, loss=0.208]
# Epoch: 2 of 10
# 100% 64/64 [01:03<00:00,  1.01it/s, loss=0.142]
# Epoch: 3 of 10
# 100% 64/64 [01:04<00:00,  1.01s/it, loss=0.134]
# Epoch: 4 of 10
# 100% 64/64 [01:05<00:00,  1.02s/it, loss=0.116]
# Epoch: 5 of 10
# 100% 64/64 [01:05<00:00,  1.03s/it, loss=0.092]
# Epoch: 6 of 10
# 100% 64/64 [01:05<00:00,  1.03s/it, loss=0.080]
# Epoch: 7 of 10
# 100% 64/64 [01:05<00:00,  1.03s/it, loss=0.075]
# Epoch: 8 of 10
# 100% 64/64 [01:06<00:00,  1.03s/it, loss=0.064]
# Epoch: 9 of 10
# 100% 64/64 [01:06<00:00,  1.04s/it, loss=0.060]
# Epoch: 10 of 10
# 100% 64/64 [01:06<00:00,  1.04s/it, loss=0.047]
# Finished training.
# ...

# %% [markdown]
# Affichage des métriques du modèle finale sélectionné

# %%
Image('learning_search/fig1.png')
